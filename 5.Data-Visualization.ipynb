-- %% [markdown]
-- <p style="text-align:center">
--     <a href="https://skills.network" target="_blank">
--     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="380" alt="Skills Network Logo">
--     </a>
-- </p>

-- %% [markdown]
-- # **Data Visualization Lab**

-- %% [markdown]
-- ## Objectives

-- %% [markdown]
-- In this lab you will perform the following:

-- %% [markdown]
-- -   Visualize the distribution of data.
--
-- -   Visualize the relationship between two features.
--
-- -   Visualize composition of data.
--
-- -   Visualize comparison of data.

-- %% [markdown]
-- <hr>

-- %% [markdown]
-- ## Demo: How to work with database

-- %% [markdown]
-- Download database file.

-- %%
!wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
-- Out:
-- --2024-09-04 01:13:38--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
-- Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
-- Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
-- HTTP request sent, awaiting response... 200 OK
-- Length: 36679680 (35M) [application/octet-stream]
-- Saving to: ‘m4_survey_data.sqlite.1’
--
-- m4_survey_data.sqli 100%[===================>]  34.98M  42.3MB/s    in 0.8s
--
-- 2024-09-04 01:13:40 (42.3 MB/s) - ‘m4_survey_data.sqlite.1’ saved [36679680/36679680]

-- %% [markdown]
-- Connect to the database.

-- %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

-- %% [markdown]
-- Import pandas module.

-- %%
%pip install plotly
-- Out:
-- ...
-- Note: you may need to restart the kernel to use updated packages.

-- %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
%matplotlib inline

-- %% [markdown]
-- ## Demo: How to run an sql query

-- %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
-- Out:
--    COUNT(*)
-- 0     11398

-- %% [markdown]
-- ## Demo: How to list all tables

-- %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
-- Out:
--                 Table_Name
-- 0                 EduOther
-- 1                  DevType
-- 2                  LastInt
-- 3               JobFactors
-- 4                 WorkPlan
-- 5            WorkChallenge
-- 6       LanguageWorkedWith
-- 7   LanguageDesireNextYear
-- 8       DatabaseWorkedWith
-- 9   DatabaseDesireNextYear
-- 10      PlatformWorkedWith
-- 11  PlatformDesireNextYear
-- 12      WebFrameWorkedWith
-- 13  WebFrameDesireNextYear
-- 14      MiscTechWorkedWith
-- 15  MiscTechDesireNextYear
-- 16              DevEnviron
-- 17              Containers
-- 18               SOVisitTo
-- 19            SONewContent
-- 20                  Gender
-- 21               Sexuality
-- 22               Ethnicity
-- 23                  master

-- %% [markdown]
-- ## Demo: How to run a group by query

-- %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
-- Out:
--      Age  count
-- 0    NaN    287
-- 1   16.0      3
-- 2   17.0      6
-- 3   18.0     29
-- 4   19.0     78
-- 5   20.0    109
-- 6   21.0    203
-- 7   22.0    406
-- 8   23.0    581
-- 9   24.0    679
-- 10  25.0    738
-- 11  26.0    720
-- 12  27.0    724
-- 13  28.0    787
-- 14  29.0    697
-- 15  30.0    651
-- 16  31.0    531
-- 17  32.0    489
-- 18  33.0    483
-- 19  34.0    395
-- 20  35.0    393
-- 21  36.0    308
-- 22  37.0    280
-- 23  38.0    279
-- 24  39.0    232
-- 25  40.0    187
-- 26  41.0    136
-- 27  42.0    162
-- 28  43.0    100
-- 29  44.0     95
-- 30  45.0     85
-- 31  46.0     66
-- 32  47.0     68
-- 33  48.0     64
-- 34  49.0     66
-- 35  50.0     57
-- 36  51.0     29
-- 37  52.0     41
-- 38  53.0     32
-- 39  54.0     26
-- 40  55.0     13
-- 41  56.0     16
-- 42  57.0     11
-- 43  58.0     12
-- 44  59.0     11
-- 45  60.0      2
-- 46  61.0     10
-- 47  62.0      5
-- 48  63.0      7
-- 49  65.0      2
-- 50  66.0      1
-- ...

-- %% [markdown]
-- ## Demo: How to describe a table

-- %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
-- Out:
-- CREATE TABLE "master" (
-- "index" INTEGER,
--   "Respondent" INTEGER,
--   "MainBranch" TEXT,
--   "Hobbyist" TEXT,
--   "OpenSourcer" TEXT,
--   "OpenSource" TEXT,
--   "Employment" TEXT,
--   "Country" TEXT,
--   "Student" TEXT,
--   "EdLevel" TEXT,
--   "UndergradMajor" TEXT,
--   "OrgSize" TEXT,
--   "YearsCode" TEXT,
--   "Age1stCode" TEXT,
--   "YearsCodePro" TEXT,
--   "CareerSat" TEXT,
--   "JobSat" TEXT,
--   "MgrIdiot" TEXT,
--   "MgrMoney" TEXT,
--   "MgrWant" TEXT,
--   "JobSeek" TEXT,
--   "LastHireDate" TEXT,
--   "FizzBuzz" TEXT,
--   "ResumeUpdate" TEXT,
--   "CurrencySymbol" TEXT,
--   "CurrencyDesc" TEXT,
--   "CompTotal" REAL,
--   "CompFreq" TEXT,
--   "ConvertedComp" REAL,
--   "WorkWeekHrs" REAL,
--   "WorkRemote" TEXT,
--   "WorkLoc" TEXT,
--   "ImpSyn" TEXT,
--   "CodeRev" TEXT,
--   "CodeRevHrs" REAL,
--   "UnitTests" TEXT,
--   "PurchaseHow" TEXT,
--   "PurchaseWhat" TEXT,
--   "OpSys" TEXT,
--   "BlockchainOrg" TEXT,
--   "BlockchainIs" TEXT,
-- ...

-- %% [markdown]
-- # Hands-on Lab

-- %% [markdown]
-- ## Visualizing distribution of data

-- %% [markdown]
-- ### Histograms

-- %% [markdown]
-- Plot a histogram of `ConvertedComp.`

-- %%
query = "SELECT * FROM master"
df = pd.read_sql(query, conn)
df.head(5)
-- Out:
--    index  Respondent                      MainBranch Hobbyist  \
-- 0      0           4  I am a developer by profession       No
-- 1      1           9  I am a developer by profession      Yes
-- 2      2          13  I am a developer by profession      Yes
-- 3      3          16  I am a developer by profession      Yes
-- 4      4          17  I am a developer by profession      Yes
--
--                                          OpenSourcer  \
-- 0                                              Never
-- 1                         Once a month or more often
-- 2  Less than once a month but more than once per ...
-- 3                                              Never
-- 4  Less than once a month but more than once per ...
--
--                                           OpenSource          Employment  \
-- 0  The quality of OSS and closed source software ...  Employed full-time
-- 1  The quality of OSS and closed source software ...  Employed full-time
-- ...

-- %%
# your code goes here
plt.figure(figsize=(12,6))
fig = px.histogram(df, x='ConvertedComp', nbins=50)
fig.update_layout(title= "Histogram of Respondents's Converted Compension",
                  xaxis_title= 'Converted Compension',
                  yaxis_title= 'Number of respondents'
                 )
fig.show()

-- %% [markdown]
-- ### Box Plots

-- %% [markdown]
-- Plot a box plot of `Age.`

-- %%
# your code goes here
plt.figure(figsize=(10,7)) 
sns.boxplot(data=df, x='Age', orient='v')

plt.xlabel("Age")
plt.ylabel("Respondent's Age")
plt.title("Age Distribution of all Respondents")
plt.show()

-- %% [markdown]
-- ## Visualizing relationships in data

-- %% [markdown]
-- ### Scatter Plots

-- %% [markdown]
-- Create a scatter plot of `Age` and `WorkWeekHrs.`

-- %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x='Age', y='WorkWeekHrs',
                marker="o",
                palette='deep')
plt.xlabel("Age")
plt.ylabel("WorkWeek Hours")
plt.title("Scatter Plot of Age and WorkWeekHrs")
plt.grid()
plt.show()

-- %% [markdown]
-- ### Bubble Plots

-- %% [markdown]
-- Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

-- %%
df[['WorkWeekHrs', 'CodeRevHrs', 'Age']]
-- Out:
--        WorkWeekHrs  CodeRevHrs   Age
-- 0             80.0         NaN  22.0
-- 1             32.0        12.0  23.0
-- 2             40.0         5.0  28.0
-- 3             40.0         NaN  26.0
-- 4             45.0         5.0  29.0
-- ...            ...         ...   ...
-- 11393         40.0         NaN  36.0
-- 11394         40.0         5.0  25.0
-- 11395         40.0         5.0  34.0
-- 11396         42.5         2.0  25.0
-- 11397         80.0         1.0  30.0
--
-- [11398 rows x 3 columns]

-- %%
# plt.figure(figsize=()) 
# plt.xlabel(")
# plt.ylabel("")
# plt.title("")
# plt.show()
plt.figure(figsize=(12,10))
sns.scatterplot(data=df, x='CodeRevHrs', y='WorkWeekHrs', size='Age', alpha=0.6, sizes=(2,1000), color='r', legend=False)
plt.show()

-- %% [markdown]
-- ## Visualizing composition of data

-- %% [markdown]
-- ### Pie Charts

-- %% [markdown]
-- Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

-- %%
œœQUERY = """
SELECT *, COUNT(*) AS count
FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
ORDER BY count DESC
LIMIT 5

"""
df = pd.read_sql_query(QUERY,conn)

data = df['count']
labels = df['DatabaseDesireNextYear']

plt.rcParams['figure.figsize'] = [8,8]

fig, ax = plt.subplots()
ax.pie(data, labels = labels, autopct='%1.1f%%', explode = (0.1, 0, 0, 0, 0), shadow = True)
plt.show()

-- %% [markdown]
-- ### Stacked Charts

-- %% [markdown]
-- Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

-- %%
# your code goes here
QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age
FROM master
WHERE Age BETWEEN 30 AND 35

"""
df = pd.read_sql_query(QUERY,conn)

work_week = df['WorkWeekHrs'].quantile(0.5)
code_rev = df['CodeRevHrs'].quantile(0.5)


plt.rcParams['figure.figsize'] = [8,8]

fig, ax = plt.subplots()

ax.bar('Age 30 - 35', work_week, label='WorkWeekHrs')
ax.bar('Age 30 - 35', code_rev, bottom=work_week, label='CodeRevHrs')
ax.legend()

plt.show()

-- %% [markdown]
-- ## Visualizing comparison of data

-- %% [markdown]
-- ### Line Chart

-- %% [markdown]
-- Plot the median `ConvertedComp` for all ages from 45 to 60.

-- %%
# your code goes here
QUERY = """
SELECT *
FROM master
WHERE Age BETWEEN 45 AND 60

"""
df = pd.read_sql_query(QUERY,conn)
df.head(5)

age_group = df.groupby('Age')['ConvertedComp'].median().reset_index()

#plot

plt.figure(figsize=(12,8))
sns.lineplot(data=age_group, x='Age', y='ConvertedComp')
plt.show()

-- %% [markdown]
-- ### Bar Chart

-- %% [markdown]
-- Create a horizontal bar chart using column `MainBranch.`

-- %%
# your code goes here
query = """
SELECT MainBranch, Count(*) AS Frequency
FROM master
GROUP BY MainBranch
"""
df= pd.read_sql(query, conn)

#plot
plt.figure(figsize=(12,6))

sns.barplot(data=df, y='MainBranch', x='Frequency', orient='h')
plt.show()

-- %% [markdown]
-- Close the database connection.

-- %%
conn.close()

-- %% [markdown]
-- <!--## Change Log

-- %% [markdown]
-- <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
-- | ----------------- | ------- | ----------------- | ---------------------------------- |
-- | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
